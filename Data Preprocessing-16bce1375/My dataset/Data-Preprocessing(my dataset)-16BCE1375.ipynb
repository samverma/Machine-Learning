# %%
import numpy as np

# %%
import pandas as pd

# %%
df= pd.read_csv('AppleStore.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             1
# 1           1             2
# 2           2             3
# 3           3             4
# 4           4             5
# 5           5             6
# 6           6             7
# 7           7             8
# 8           8             9
# 9           9            10
#
#                                             app_name currency  price  \
# 0                                    PAC-MAN Premium      USD   3.99
# 1                          Evernote - stay organized      USD   0.00
# 2    WeatherBug - Local Weather, Radar, Maps, Alerts      USD   0.00
# 3  eBay: Best App to Buy, Sell, Save! Online Shop...      USD   0.00
# 4                                              Bible      USD   0.00
# 5                                   Shanghai Mahjong      USD   0.99
# 6             PayPal - Send and request money safely      USD   0.00
# 7                            Pandora - Music & Radio      USD   0.00
# ...

# %%
df.drop(['id','size_bytes','rating_count_ver','user_rating_ver','ver','vpp_lic','lang.num','ipadSc_urls.num',
         'lang.num' ],1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-a750161fbb70> in <module>()
#       1 df.drop(['id','size_bytes','rating_count_ver','user_rating_ver','ver','vpp_lic','lang.num','ipadSc_urls.num',
# ----> 2          'lang.num' ],1,inplace=True)
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    1875                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1876             else:
# -> 1877                 new_axis = axis.drop(labels, errors=errors)
#    1878             dropped = self.reindex(**{axis_name: new_axis})
#    1879             try:
#
# C:\Anaconda3\lib\site-packages\pandas\indexes\base.py in drop(self, labels, errors)
#    3049             if errors != 'ignore':
#    3050                 raise ValueError('labels %s not contained in axis' %
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             1
# 1           1             2
# 2           2             3
# 3           3             4
# 4           4             5
# 5           5             6
# 6           6             7
# 7           7             8
# 8           8             9
# 9           9            10
#
#                                             app_name currency  price  \
# 0                                    PAC-MAN Premium      USD   3.99
# 1                          Evernote - stay organized      USD   0.00
# 2    WeatherBug - Local Weather, Radar, Maps, Alerts      USD   0.00
# 3  eBay: Best App to Buy, Sell, Save! Online Shop...      USD   0.00
# 4                                              Bible      USD   0.00
# 5                                   Shanghai Mahjong      USD   0.99
# 6             PayPal - Send and request money safely      USD   0.00
# 7                            Pandora - Music & Radio      USD   0.00
# ...

# %%
df = df.rename(columns={'track_name':'app_name', 'prime_genre':'genre', 'sup_devices.num':'supporteddevice'})

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  \
# 0           0             1
# 1           1             2
# 2           2             3
# 3           3             4
# 4           4             5
#
#                                             app_name currency  price  \
# 0                                    PAC-MAN Premium      USD   3.99
# 1                          Evernote - stay organized      USD   0.00
# 2    WeatherBug - Local Weather, Radar, Maps, Alerts      USD   0.00
# 3  eBay: Best App to Buy, Sell, Save! Online Shop...      USD   0.00
# 4                                              Bible      USD   0.00
#
#    rating_count_tot  user_rating cont_rating         genre  supporteddevice
# 0             21292          4.0          4+         Games               38
# 1            161065          4.0          4+  Productivity               37
# 2            188583          3.5          4+       Weather               37
# ...

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %%
sb.pairplot(df.dropna(), hue='genre')
# Out:
# C:\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
df.loc[df['genre']== 'Games', 'user_rating'].hist()

# %%
df.to_csv('AppleStorenew.csv', encoding='utf-8')

# %% [markdown]
# # CON
